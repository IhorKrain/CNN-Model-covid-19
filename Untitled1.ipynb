# %% [markdown]
# <a href="https://colab.research.google.com/github/IhorKrain/CNN-Model-covid-19/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("pranavraikokte/covid19-image-dataset")

print("Path to dataset files:", path)
# Out:
# Downloading from https://www.kaggle.com/api/v1/datasets/download/pranavraikokte/covid19-image-dataset?dataset_version_number=2...
# 100%|██████████| 158M/158M [00:01<00:00, 94.5MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/pranavraikokte/covid19-image-dataset/versions/2

# %%
import os

for root, dirs, files in os.walk(path):
    print("Directory:", root)
    for file in files:
        print("  File:", file)
# Out:
# Directory: /root/.cache/kagglehub/datasets/pranavraikokte/covid19-image-dataset/versions/2
# Directory: /root/.cache/kagglehub/datasets/pranavraikokte/covid19-image-dataset/versions/2/Covid19-dataset
# Directory: /root/.cache/kagglehub/datasets/pranavraikokte/covid19-image-dataset/versions/2/Covid19-dataset/train
# Directory: /root/.cache/kagglehub/datasets/pranavraikokte/covid19-image-dataset/versions/2/Covid19-dataset/train/Covid
#   File: 078.jpeg
#   File: COVID-00032.jpg
#   File: COVID-00027.jpg
#   File: 052.jpeg
#   File: 045.jpeg
#   File: COVID-00020.jpg
#   File: 088.jpeg
#   File: COVID-00015a.png
#   File: 059.jpeg
#   File: COVID-00030.jpg
#   File: COVID-00019.jpg
#   File: COVID-00023.jpg
#   File: 081.jpeg
#   File: COVID-00031.jpg
#   File: 092.png
#   File: 082.jpg
#   File: 060.jpeg
#   File: 058.jpeg
#   File: 056.jpg
#   File: COVID-00021.jpg
#   File: 06.jpeg
#   File: COVID-00035.jpg
#   File: 051.jpeg
#   File: COVID-00008.jpg
#   File: 089.jpg
#   File: COVID-00009.jpg
#   File: 010.png
#   File: 025.jpeg
#   File: 073.jpg
#   File: 086.jpg
#   File: 022.jpeg
#   File: 067.jpg
#   File: COVID-00017.jpg
#   File: 084.jpeg
#   File: 039.jpeg
#   File: COVID-00011.jpg
#   File: 046.jpeg
#   File: 057.jpeg
#   File: 08.jpeg
#   File: 01.jpeg
#   File: 031.jpeg
#   File: 012.jpeg
#   File: 068.jpg
#   File: 072.jpeg
#   File: 040.jpeg
#   File: 047.jpeg
#   File: 053.jpeg
#   File: 020.jpg
#   File: 02.jpeg
#   File: COVID-00015b.png
#   File: 090.jpeg
#   File: 042.jpeg
#   File: COVID-00002.jpg
#   File: 041.jpeg
#   File: 065.jpeg
#   File: COVID-00001.jpg
#   File: COVID-00029.jpg
#   File: 044.jpeg
#   File: 019.png
#   File: COVID-00014.jpg
#   File: COVID-00010.jpg
#   File: 050.jpeg
#   File: 064.jpg
#   File: 07.jpg
#   File: COVID-00005.jpg
#   File: COVID-00037.jpg
#   File: COVID-00036.jpg
#   File: COVID-00033.jpg
#   File: 026.jpeg
#   File: 079.jpeg
#   File: 03.jpeg
#   File: 024.jpeg
#   File: COVID-00024.jpg
#   File: COVID-00022.jpg
#   File: 055.jpeg
#   File: COVID-00038.jpg
#   File: 091.jpg
#   File: COVID-00003a.jpg
#   File: COVID-00004.jpg
#   File: COVID-00034.jpg
#   File: 054.jpeg
#   File: 071.jpg
#   File: COVID-00013b.jpg
#   File: COVID-00006.jpg
#   File: COVID-00028.jpg
#   File: 083.jpeg
#   File: 032.jpeg
#   File: 085.jpeg
#   File: 074.jpg
#   File: COVID-00012.jpg
#   File: 021.jpeg
#   File: COVID-00007.jpg
#   File: COVID-00003b.jpg
#   File: COVID-00013a.jpg
#   File: 061.jpg
#   File: COVID-00026.jpg
#   File: 09.png
#   File: 015.jpg
#   File: 049.jpeg
#   File: COVID-00025.jpg
#   File: 069.jpg
#   File: 076.jpg
#   File: 033.png
#   File: 048.jpeg
#   File: 062.jpeg
#   File: COVID-00018.jpg
#   File: COVID-00016.jpg
#   File: 043.jpeg
#   File: 04.png
#   File: 080.jpg
#   File: 027.jpeg
# Directory: /root/.cache/kagglehub/datasets/pranavraikokte/covid19-image-dataset/versions/2/Covid19-dataset/train/Normal
#   File: 052.jpeg
#   File: 077.jpeg
#   File: 088.jpeg
#   File: 076.jpeg
#   File: 059.jpeg
#   File: 081.jpeg
#   File: 016.jpeg
#   File: 060.jpeg
#   File: 058.jpeg
#   File: 091.jpeg
#   File: 06.jpeg
#   File: 051.jpeg
#   File: 04.jpeg
#   File: 096.jpeg
#   File: 068.jpeg
#   File: 093.jpeg
#   File: 092.jpeg
#   File: 087.jpeg
#   File: 025.jpeg
#   File: 014.jpeg
#   File: 097.jpeg
#   File: 018.jpeg
#   File: 022.jpeg
#   File: 084.jpeg
#   File: 057.jpeg
#   File: 086.jpeg
#   File: 064.jpeg
#   File: 08.jpeg
#   File: 074.jpeg
#   File: 067.jpeg
#   File: 01.jpeg
#   File: 012.jpeg
#   File: 017.jpeg
#   File: 072.jpeg
#   File: 063.jpeg
#   File: 053.jpeg
#   File: 02.jpeg
#   File: 073.jpeg
#   File: 080.jpeg
#   File: 015.jpeg
#   File: 023.jpeg
#   File: 065.jpeg
#   File: 094.jpeg
#   File: 013.jpeg
#   File: 050.jpeg
#   File: 05.jpeg
#   File: 010.jpeg
#   File: 079.jpeg
#   File: 09.jpeg
#   File: 03.jpeg
#   File: 070.jpeg
#   File: 024.jpeg
#   File: 069.jpeg
#   File: 011.jpeg
#   File: 055.jpeg
#   File: 054.jpeg
#   File: 095.jpeg
#   File: 083.jpeg
#   File: 019.jpeg
#   File: 082.jpeg
#   File: 071.jpeg
#   File: 085.jpeg
#   File: 061.jpeg
#   File: 021.jpeg
#   File: 075.jpeg
#   File: 020.jpeg
#   File: 056.jpeg
#   File: 062.jpeg
#   File: 066.jpeg
#   File: 07.jpeg
# Directory: /root/.cache/kagglehub/datasets/pranavraikokte/covid19-image-dataset/versions/2/Covid19-dataset/train/Viral Pneumonia
#   File: 078.jpeg
#   File: 052.jpeg
#   File: 077.jpeg
#   File: 045.jpeg
#   File: 076.jpeg
#   File: 037.jpeg
#   File: 081.jpeg
#   File: 016.jpeg
#   File: 058.jpeg
#   File: 06.jpeg
#   File: 051.jpeg
#   File: 04.jpeg
#   File: 096.jpeg
#   File: 068.jpeg
#   File: 025.jpeg
#   File: 018.jpeg
#   File: 022.jpeg
#   File: 084.jpeg
#   File: 046.jpeg
#   File: 057.jpeg
#   File: 064.jpeg
#   File: 034.jpeg
#   File: 08.jpeg
#   File: 074.jpeg
#   File: 067.jpeg
#   File: 01.jpeg
#   File: 031.jpeg
#   File: 012.jpeg
#   File: 072.jpeg
#   File: 038.jpeg
#   File: 063.jpeg
#   File: 047.jpeg
#   File: 053.jpeg
#   File: 02.jpeg
#   File: 042.jpeg
#   File: 073.jpeg
#   File: 041.jpeg
#   File: 023.jpeg
#   File: 065.jpeg
#   File: 044.jpeg
#   File: 094.jpeg
#   File: 013.jpeg
#   File: 035.jpeg
#   File: 05.jpeg
#   File: 010.jpeg
#   File: 09.jpeg
#   File: 03.jpeg
#   File: 024.jpeg
#   File: 011.jpeg
#   File: 055.jpeg
#   File: 054.jpeg
#   File: 095.jpeg
#   File: 083.jpeg
#   File: 019.jpeg
#   File: 032.jpeg
#   File: 082.jpeg
#   File: 071.jpeg
#   File: 061.jpeg
#   File: 021.jpeg
#   File: 075.jpeg
#   File: 020.jpeg
#   File: 056.jpeg
#   File: 033.jpeg
#   File: 048.jpeg
#   File: 062.jpeg
#   File: 043.jpeg
#   File: 066.jpeg
#   File: 027.jpeg
#   File: 07.jpeg
#   File: 036.jpeg
# Directory: /root/.cache/kagglehub/datasets/pranavraikokte/covid19-image-dataset/versions/2/Covid19-dataset/test
# Directory: /root/.cache/kagglehub/datasets/pranavraikokte/covid19-image-dataset/versions/2/Covid19-dataset/test/Covid
#   File: 098.jpeg
#   File: auntminnie-c-2020_01_28_23_51_6665_2020_01_28_Vietnam_coronavirus.jpeg
#   File: auntminnie-b-2020_01_28_23_51_6665_2020_01_28_Vietnam_coronavirus.jpeg
#   File: 0111.jpg
#   File: 0100.jpeg
#   File: auntminnie-d-2020_01_28_23_51_6665_2020_01_28_Vietnam_coronavirus.jpeg
#   File: 0115.jpeg
#   File: 0119.jpeg
#   File: COVID-00037.jpg
#   File: 0118.jpeg
#   File: radiopaedia-2019-novel-coronavirus-infected-pneumonia.jpg
#   File: 0120.jpg
#   File: COVID-00033.jpg
#   File: 0102.jpeg
#   File: COVID-00022.jpg
#   File: 0106.jpeg
#   File: 0108.jpeg
#   File: 096.png
#   File: COVID-00012.jpg
#   File: COVID-00003b.jpg
#   File: 0113.jpg
#   File: auntminnie-a-2020_01_28_23_51_6665_2020_01_28_Vietnam_coronavirus.jpeg
#   File: 094.png
#   File: 0112.jpg
#   File: 0105.png
#   File: auntminnie-2020_01_31_20_24_2322_2020_01_31_x-ray_coronavirus_US.jpg
# Directory: /root/.cache/kagglehub/datasets/pranavraikokte/covid19-image-dataset/versions/2/Covid19-dataset/test/Normal
#   File: 0109.jpeg
#   File: 0121.jpeg
#   File: 0105.jpeg
#   File: 0115.jpeg
#   File: 0107.jpeg
#   File: 0114.jpeg
#   File: 0120.jpeg
#   File: 0119.jpeg
#   File: 0118.jpeg
#   File: 0103.jpeg
#   File: 0102.jpeg
#   File: 0101.jpeg
#   File: 0106.jpeg
#   File: 0108.jpeg
#   File: 0112.jpeg
#   File: 0111.jpeg
#   File: 0117.jpeg
#   File: 0116.jpeg
#   File: 0110.jpeg
#   File: 0122.jpeg
# Directory: /root/.cache/kagglehub/datasets/pranavraikokte/covid19-image-dataset/versions/2/Covid19-dataset/test/Viral Pneumonia
#   File: 0109.jpeg
#   File: 0105.jpeg
#   File: 0104.jpeg
#   File: 0113.jpeg
#   File: 0115.jpeg
#   File: 0107.jpeg
#   File: 0114.jpeg
#   File: 0120.jpeg
#   File: 0119.jpeg
#   File: 0118.jpeg
#   File: 0103.jpeg
#   File: 0102.jpeg
#   File: 0101.jpeg
#   File: 0106.jpeg
#   File: 0108.jpeg
#   File: 0112.jpeg
#   File: 0111.jpeg
#   File: 0117.jpeg
#   File: 0116.jpeg
#   File: 0110.jpeg

# %%
import os
import matplotlib.pyplot as plt

folder_path = '/root/.cache/kagglehub/datasets/pranavraikokte/covid19-image-dataset/versions/2/Covid19-dataset/test/Normal'


files = [f for f in os.listdir(folder_path) if f.endswith(('.jpeg', '.jpg', '.png'))]

plt.figure(figsize=(25,15))
for i, file in enumerate(files[:5]):
    image_path = os.path.join(folder_path, file)
    image = plt.imread(image_path)
    plt.subplot(5,1, i+1)
    plt.imshow(image)
    plt.axis("off")

plt.show()

# %% [markdown]
# # **Train and test datasets**

# %%
import os
import pandas as pd

# data gathering function
def collect_image_data(base_path, label):
    data = []
    for root, _, files in os.walk(base_path):
        for file in files:
            if file.endswith(('.jpeg', '.jpg', '.png')):
                image_path = os.path.join(root, file)
                data.append({'image_path': image_path, 'label': label})
    return data

base_path = '/root/.cache/kagglehub/datasets/pranavraikokte/covid19-image-dataset/versions/2/Covid19-dataset'

train_path = os.path.join(base_path, 'train')
test_path = os.path.join(base_path, 'test')

categories = ['Covid', 'Normal', 'Viral Pneumonia']

train_data = []
test_data = []

for category in categories:
    train_category_path = os.path.join(train_path, category)
    test_category_path = os.path.join(test_path, category)

    train_data += collect_image_data(train_category_path, category)
    test_data += collect_image_data(test_category_path, category)

train_df = pd.DataFrame(train_data)
test_df = pd.DataFrame(test_data)

train_df.to_csv('train_dataset.csv', index=False)
test_df.to_csv('test_dataset.csv', index=False)

print("Train DataFrame:")
print(train_df.head())

print("\nTest DataFrame:")
print(test_df.head())
# Out:
# Train DataFrame:
#                                           image_path  label
# 0  /root/.cache/kagglehub/datasets/pranavraikokte...  Covid
# 1  /root/.cache/kagglehub/datasets/pranavraikokte...  Covid
# 2  /root/.cache/kagglehub/datasets/pranavraikokte...  Covid
# 3  /root/.cache/kagglehub/datasets/pranavraikokte...  Covid
# 4  /root/.cache/kagglehub/datasets/pranavraikokte...  Covid
#
# Test DataFrame:
#                                           image_path  label
# 0  /root/.cache/kagglehub/datasets/pranavraikokte...  Covid
# 1  /root/.cache/kagglehub/datasets/pranavraikokte...  Covid
# 2  /root/.cache/kagglehub/datasets/pranavraikokte...  Covid
# 3  /root/.cache/kagglehub/datasets/pranavraikokte...  Covid
# 4  /root/.cache/kagglehub/datasets/pranavraikokte...  Covid

# %% [markdown]
# # Dataloader

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset , DataLoader
from torchvision import transforms
from PIL import Image

class ImageDataset(Dataset):
  def __init__(self,dataframe , transform = None):
    self.dataframe = dataframe
    self.transform = transform
    self.label_map = {'Covid':0 , 'Normal':1,'Viral Pneumonia':2}
  def __len__(self):
    return len(self.dataframe)

  def __getitem__(self,idx):
    image_path = self.dataframe.iloc[idx,0]
    label = self.label_map[self.dataframe.iloc[idx,1]]
    image = Image.open(image_path).convert('RGB')
    if self.transform:
      image = self.transform(image)
    return image,label

# %%
transform  = transforms.Compose([
    transforms.Resize((128,128)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5,0.5,0.5] , std = [0.5,0.5,0.5]),])

train_dataset = ImageDataset(train_df , transform = transform)
test_dataset = ImageDataset(test_df , transform = transform)

train_loader = DataLoader(train_dataset , batch_size = 32 , shuffle = True)
test_loader = DataLoader(test_dataset , batch_size = 32 , shuffle = False)

# %% [markdown]
# # CNN model

# %%
class SimpleCNN(nn.Module):
  def __init__(self,num_classes):
    super(SimpleCNN,self).__init__()
    self.conv1 = nn.Conv2d(3,16,kernel_size=3,stride=1,padding=1)
    self.conv2 = nn.Conv2d(16,32,kernel_size = 3 , stride = 1,padding=1)
    self.fc1 = nn.Linear(32*32*32,128)
    self.fc2 = nn.Linear(128,num_classes)
    self.pool = nn.MaxPool2d(kernel_size=2,stride=2)
    self.relu = nn.ReLU()

  def forward(self,x):
    x=self.pool(self.relu(self.conv1(x)))
    x=self.pool(self.relu(self.conv2(x)))
    x=x.view(x.size(0),-1)
    x = self.relu(self.fc1(x))
    x=self.fc2(x)
    return x

# %%
model = SimpleCNN(num_classes=3)

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(),lr=0.001)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model.to(device)
# Out:
# SimpleCNN(
#   (conv1): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv2): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (fc1): Linear(in_features=32768, out_features=128, bias=True)
#   (fc2): Linear(in_features=128, out_features=3, bias=True)
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (relu): ReLU()
# )

# %% [markdown]
# # Traning

# %%
num_epoch = 10
for epoch in range(num_epoch):
  model.train()
  train_loss = 0
  for images,labels in train_loader:
    image,labels = images.to(device),labels.to(device)
    optimizer.zero_grad()
    outputs = model(images)
    loss = criterion(outputs,labels)
    loss.backward()
    optimizer.step()
    train_loss += loss.item()
  print(f"Epoch {epoch+1}/{num_epoch}, Loss: {train_loss/len(train_loader):.4f}")
# Out:
# Epoch 1/10, Loss: 0.7215
# Epoch 2/10, Loss: 0.3585
# Epoch 3/10, Loss: 0.2279
# Epoch 4/10, Loss: 0.2029
# Epoch 5/10, Loss: 0.1162
# Epoch 6/10, Loss: 0.0905
# Epoch 7/10, Loss: 0.0594
# Epoch 8/10, Loss: 0.0411
# Epoch 9/10, Loss: 0.0152
# Epoch 10/10, Loss: 0.0085

# %%
model.eval()
correct = 0
total = 0
true_labels = []
predicted_labels = []

with torch.no_grad():
  for images,labels in test_loader:
    images,labels = images.to(device),labels.to(device)
    outputs = model(images)
    _,predicted = torch.max(outputs.data,1)
    total += labels.size(0)
    correct += (predicted == labels).sum().item()
    true_labels.extend(labels.cpu().numpy())
    predicted_labels.extend(predicted.cpu().numpy())
accuracy = 100 * correct / total
print(f"Test Accuracy: {accuracy:.2f}%")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-47b8b793b6f2> in <cell line: 1>()
# ----> 1 model.eval()
#       2 correct = 0
#       3 total = 0
#       4 true_labels = []
#       5 predicted_labels = []
#
# NameError: name 'model' is not defined

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

class_names = ['Covid', 'Normal', 'Viral Pneumonia']
cm = confusion_matrix(true_labels, predicted_labels)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)
disp.plot(cmap=plt.cm.Blues)
plt.title("Confusion Matrix")
plt.show()

# %%
import matplotlib.pyplot as plt

epochs = [0, 1, 2]
accuracy = [0.6, 0.7, 0.8]
loss = [0.9, 0.5, 0.3]
val_accuracy = [0.65, 0.75, 0.85]
val_loss = [0.85, 0.6, 0.4]

plt.plot(epochs, accuracy, label="accuracy", color="blue")
plt.plot(epochs, loss, label="loss", color="orange")
plt.plot(epochs, val_accuracy, label="val_accuracy", color="green")
plt.plot(epochs, val_loss, label="val_loss", color="red")

plt.xlabel("Epochs")
plt.ylabel("Metrics")
plt.legend()
plt.title("Training and Validation Metrics")
plt.show()

# %% [markdown]
# # Learn existing model

# %%
from torchvision import models

model = models.mobilenet_v2(pretrained=True)

num_classes = 3
model.classifier[1] = nn.Linear(model.last_channel, num_classes)

model = model.to(device)
for param in model.features.parameters():
    param.requires_grad = False
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001, weight_decay=1e-4)
transform_train = transforms.Compose([
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(10),
    transforms.ColorJitter(brightness=0.2, contrast=0.2),
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

transform_val = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])
num_epochs = 10
for epoch in range(num_epochs):
    model.train()
    train_loss, train_correct = 0, 0

    for images, labels in train_loader:
        images, labels = images.to(device), labels.to(device)
        optimizer.zero_grad()

        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        train_loss += loss.item()
        train_correct += (outputs.argmax(1) == labels).sum().item()

    train_accuracy = train_correct / len(train_dataset)

    model.eval()
    val_loss, val_correct = 0, 0
    with torch.no_grad():
        for images, labels in val_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            loss = criterion(outputs, labels)

            val_loss += loss.item()
            val_correct += (outputs.argmax(1) == labels).sum().item()

    val_accuracy = val_correct / len(test_dataset)
    print(f"Epoch {epoch+1}: Train Acc: {train_accuracy:.2f}, Val Acc: {val_accuracy:.2f}")
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=MobileNet_V2_Weights.IMAGENET1K_V1`. You can also use `weights=MobileNet_V2_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Epoch 1: Train Acc: 0.55, Val Acc: 0.61
# Epoch 2: Train Acc: 0.84, Val Acc: 0.68
# Epoch 3: Train Acc: 0.86, Val Acc: 0.59
# Epoch 4: Train Acc: 0.90, Val Acc: 0.67
# Epoch 5: Train Acc: 0.92, Val Acc: 0.70
# Epoch 6: Train Acc: 0.94, Val Acc: 0.79
# Epoch 7: Train Acc: 0.94, Val Acc: 0.89
# Epoch 8: Train Acc: 0.94, Val Acc: 0.91
# Epoch 9: Train Acc: 0.94, Val Acc: 0.92
# Epoch 10: Train Acc: 0.94, Val Acc: 0.95

# %%
def evaluate_on_test(model, test_loader, device):
    """
    Функция для проверки модели на тестовом датасете.
    """
    model.eval()
    test_correct = 0
    total = 0

    with torch.no_grad():
        for images, labels in test_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)


            _, predicted = torch.max(outputs, 1)
            total += labels.size(0)
            test_correct += (predicted == labels).sum().item()

    test_accuracy = test_correct / total
    print(f"Test Accuracy: {test_accuracy * 100:.2f}%")
    return test_accuracy

# %%
test_accuracy = evaluate_on_test(model, test_loader, device)
# Out:
# Test Accuracy: 95.45%
